# %%
# Puxa as variáveis do arquivo Conversores para serem utilizadas neste arquivo
# %run Conversores.ipynb

# %% [markdown]
# # Meta 5 - 2023

# %%
# Meta 5 - 2023
# Iniciando navegador
driver = webdriver.Chrome()
sleep(3)

# %%
# Entrando no site
driver.get(ano[2023])
sleep(8)

# %%
# Fechando pop-up
driver.find_element(By.CLASS_NAME, 'tileSVG').click()
sleep(1)

# %%
# Clicando na meta 
driver.find_elements(By.CLASS_NAME, 'tileSVG')[6].click()
sleep(3)

# %%
# Selecionando o UF
driver.find_elements(By.CSS_SELECTOR, '.slicer-dropdown-menu')[2].click()
sleep(2)

# %%
# Selecionando 07ª - CE
driver.find_elements(By.CSS_SELECTOR, '.slicerText')[7].click()
sleep(5)

# %%
# Selecionando a 1º Instância
driver.find_elements(By.CSS_SELECTOR, '.slicer-dropdown-menu')[0].click()
sleep(2)

driver.find_elements(By.CSS_SELECTOR, '.slicerText')[1].click()
sleep(5)

# %%
table = driver.find_elements(By.XPATH, '//*[@id="pvExplorationHost"]/div/div/exploration/div/explore-canvas/div/div[2]/div/div[2]/div[2]/visual-container-repeat/visual-container[16]/transform/div/div[3]/div/div/visual-modern/div/div/div[2]/div[1]/div[2]/div/div')
table = [r.text for r in table]

# %%
# Tabela só é usada para scrollar, table que armazena os dados
tabela = driver.find_elements(By.CLASS_NAME, 'mid-viewport')[1]
driver.execute_script("arguments[0].scrollTop += 500;", tabela)
sleep(2)

# %%
table2 = driver.find_elements(By.XPATH, '//*[@id="pvExplorationHost"]/div/div/exploration/div/explore-canvas/div/div[2]/div/div[2]/div[2]/visual-container-repeat/visual-container[16]/transform/div/div[3]/div/div/visual-modern/div/div/div[2]/div[1]/div[2]/div/div')
table2 = [r.text for r in table2]

# %%
total1grau = driver.find_elements(By.XPATH, '//*[@id="pvExplorationHost"]/div/div/exploration/div/explore-canvas/div/div[2]/div/div[2]/div[2]/visual-container-repeat/visual-container[16]/transform/div/div[3]/div/div/visual-modern/div/div/div[2]/div[1]/div[3]/div')
total1grau = [r.text for r in total1grau]
total1grau = [r.split('\n') for r in total1grau]
total1grau = total1grau[0]
total1grau = [total1grau[0], total1grau[-1]]
total1grau[0] = 'Total do 1º Grau'
sleep(2)

# %%
# Selecionando todos os graus
driver.find_elements(By.CSS_SELECTOR, '.slicerText')[1].click()
sleep(5)

# %%
totaltrt7 = driver.find_elements(By.XPATH, '//*[@id="pvExplorationHost"]/div/div/exploration/div/explore-canvas/div/div[2]/div/div[2]/div[2]/visual-container-repeat/visual-container[13]/transform/div/div[3]/div/div/visual-modern/div/div/div[2]/div[1]/div[3]/div')
totaltrt7 = [r.text for r in totaltrt7]
totaltrt7 = [r.split('\n') for r in totaltrt7]
totaltrt7 = totaltrt7[0]
totaltrt7 = [totaltrt7[0], totaltrt7[-1]]
totaltrt7[0] = 'Total da 7ª Região'

# %%
tableFull = table + table2 
tableFull
# Out:
# ['Aracati - Vara Única\n1.416\n939\n39,87%\nFormatação Condicional Adicional\n18,87%\n57,29%\n118,73%',
#  'Baturité - Vara Única\n624\n880\n58,51%\nFormatação Condicional Adicional\n20,95%\n73,76%\n100,88%',
#  'Caucaia - 1ª Vara\n2.713\n1.304\n32,46%\nFormatação Condicional Adicional\n22,62%\n37,87%\n204,63%',
#  'Caucaia - 2ª Vara\n1.214\n896\n42,46%\nFormatação Condicional Adicional\n31,71%\n58,41%\n105,81%',
#  'Crateús - Vara Única\n2.087\n1.071\n33,91%\nFormatação Condicional Adicional\n25,65%\n47,25%\n119,32%',
#  'Eusébio - Vara Única\n2.951\n917\n23,71%\nFormatação Condicional Adicional\n26,87%\n16,07%\n120,91%',
#  'Fortaleza - 10ª Vara\n2.840\n2.004\n41,37%\nFormatação Condicional Adicional\n22,76%\n54,03%\n137,38%',
#  'Fortaleza - 11ª Vara\n2.764\n1.015\n26,86%\nFormatação Condicional Adicional\n17,39%\n32,71%\n198,32%',
#  'Fortaleza - 12ª Vara\n2.433\n2.676\n52,38%\nFormatação Condicional Adicional\n26,65%\n67,67%\n117,05%',
#  'Fortaleza - 13ª Vara\n2.232\n1.627\n42,16%\nFormatação Condicional Adicional\n31,92%\n51,56%\n110,62%',
#  'Fortaleza - 14ª Vara\n2.594\n1.189\n31,43%\nFormatação Condicional Adicional\n23,15%\n38,26%\n172,53%',
#  'Fortaleza - 15ª Vara\n2.180\n1.551\n41,57%\nFormatação Condicional Adicional\n28,77%\n54,66%\n130,64%',
#  'Fortaleza - 16ª Vara\n2.280\n954\n29,50%\nFormatação Condicional Adicional\n19,91%\n41,90%\n144,65%',
#  'Fortaleza - 17ª Vara\n2.079\n1.586\n43,27%\nFormatação Condicional Adicional\n31,52%\n54,24%\n137,22%',
#  'Fortaleza - 18ª Vara\n1.718\n637\n27,05%\nFormatação Condicional Adicional\n19,44%\n37,45%\n66,85%',
#  'Fortaleza - 1ª Vara\n2.542\n1.928\n43,13%\nFormatação Condicional Adicional\n30,63%\n50,64%\n115,20%',
#  'Fortaleza - 2ª Vara\n2.312\n1.599\n40,88%\nFormatação Condicional Adicional\n33,48%\n47,04%\n134,90%',
#  'Fortaleza - 3ª Vara\n2.040\n2.852\n58,30%\nFormatação Condicional Adicional\n39,51%\n72,49%\n112,41%',
#  'Fortaleza - 4ª Vara\n2.008\n2.977\n59,72%\nFormatação Condicional Adicional\n37,00%\n74,98%\n114,27%',
#  'Fortaleza - 5ª Vara\n2.846\n1.950\n40,66%\nFormatação Condicional Adicional\n30,00%\n51,19%\n145,31%',
#  'Fortaleza - 5ª Vara\n2.846\n1.950\n40,66%\nFormatação Condicional Adicional\n30,00%\n51,19%\n145,31%',
#  'Fortaleza - 6ª Vara\n1.579\n1.787\n53,09%\nFormatação Condicional Adicional\n47,50%\n62,21%\n77,35%',
#  'Fortaleza - 7ª Vara\n2.391\n1.919\n44,52%\nFormatação Condicional Adicional\n34,05%\n53,19%\n123,25%',
#  'Fortaleza - 8ª Vara\n2.278\n1.268\n35,76%\nFormatação Condicional Adicional\n26,68%\n46,76%\n134,31%',
#  'Fortaleza - 9ª Vara\n2.139\n2.662\n55,45%\nFormatação Condicional Adicional\n43,69%\n65,40%\n105,16%',
#  'Iguatu - Vara Única\n3.251\n1.566\n32,51%\nFormatação Condicional Adicional\n19,81%\n47,43%\n111,43%',
#  'Limoeiro do Norte - Vara Única\n2.155\n1.427\n39,84%\nFormatação Condicional Adicional\n29,24%\n45,46%\n81,18%',
#  'Maracanaú - 1ª Vara\n2.636\n1.038\n28,25%\nFormatação Condicional Adicional\n24,65%\n32,51%\n126,10%',
#  'Maracanaú - 2ª Vara\n2.441\n711\n22,56%\nFormatação Condicional Adicional\n21,40%\n23,99%\n114,26%',
#  'Pacajus - Vara Única\n2.604\n1.391\n34,82%\nFormatação Condicional Adicional\n33,68%\n35,34%\n134,79%',
#  'Quixadá - Vara Única\n1.630\n1.935\n54,28%\nFormatação Condicional Adicional\n46,45%\n58,59%\n105,75%',
#  'Região do Cariri - 1ª Vara\n2.726\n1.505\n35,57%\nFormatação Condicional Adicional\n30,40%\n40,25%\n-1,41%',
#  'Região do Cariri - 2ª Vara\n4.210\n3.469\n45,18%\nFormatação Condicional Adicional\n22,54%\n54,83%\n-1,11%',
#  'Região do Cariri - 3ª Vara\n2.987\n2.260\n43,07%\nFormatação Condicional Adicional\n28,15%\n55,46%\n-1,16%',
#  'São Gonçalo do Amarante - Vara Única\n3.243\n891\n21,55%\nFormatação Condicional Adicional\n21,83%\n19,89%\n147,36%',
#  'Sobral - 1ª Vara\n2.611\n1.096\n29,57%\nFormatação Condicional Adicional\n32,39%\n24,76%\n125,88%',
#  'Sobral - 2ª Vara\n2.445\n908\n27,08%\nFormatação Condicional Adicional\n26,02%\n27,84%\n98,37%',
#  'Tianguá - Vara Única\n3.137\n1.411\n31,02%\nFormatação Condicional Adicional\n25,37%\n36,29%\n100,95%']

# %%
# Transforma cada linha em uma lista separada por \n 
tableFull = [r.split('\n') for r in tableFull]

# %%
# Remove todos os elementos de cada linha(lista), deixando apenas o primeiro e último (unidade judiciária e cumprimento da meta)
tableFull = [[l[0], l[-1]] for l in tableFull]
tableFull
# Out:
# [['Aracati - Vara Única', '118,73%'],
#  ['Baturité - Vara Única', '100,88%'],
#  ['Caucaia - 1ª Vara', '204,63%'],
#  ['Caucaia - 2ª Vara', '105,81%'],
#  ['Crateús - Vara Única', '119,32%'],
#  ['Eusébio - Vara Única', '120,91%'],
#  ['Fortaleza - 10ª Vara', '137,38%'],
#  ['Fortaleza - 11ª Vara', '198,32%'],
#  ['Fortaleza - 12ª Vara', '117,05%'],
#  ['Fortaleza - 13ª Vara', '110,62%'],
#  ['Fortaleza - 14ª Vara', '172,53%'],
#  ['Fortaleza - 15ª Vara', '130,64%'],
#  ['Fortaleza - 16ª Vara', '144,65%'],
#  ['Fortaleza - 17ª Vara', '137,22%'],
#  ['Fortaleza - 18ª Vara', '66,85%'],
#  ['Fortaleza - 1ª Vara', '115,20%'],
#  ['Fortaleza - 2ª Vara', '134,90%'],
#  ['Fortaleza - 3ª Vara', '112,41%'],
#  ['Fortaleza - 4ª Vara', '114,27%'],
#  ['Fortaleza - 5ª Vara', '145,31%'],
#  ['Fortaleza - 5ª Vara', '145,31%'],
#  ['Fortaleza - 6ª Vara', '77,35%'],
#  ['Fortaleza - 7ª Vara', '123,25%'],
#  ['Fortaleza - 8ª Vara', '134,31%'],
#  ['Fortaleza - 9ª Vara', '105,16%'],
#  ['Iguatu - Vara Única', '111,43%'],
#  ['Limoeiro do Norte - Vara Única', '81,18%'],
#  ['Maracanaú - 1ª Vara', '126,10%'],
#  ['Maracanaú - 2ª Vara', '114,26%'],
#  ['Pacajus - Vara Única', '134,79%'],
#  ['Quixadá - Vara Única', '105,75%'],
#  ['Região do Cariri - 1ª Vara', '-1,41%'],
#  ['Região do Cariri - 2ª Vara', '-1,11%'],
#  ['Região do Cariri - 3ª Vara', '-1,16%'],
#  ['São Gonçalo do Amarante - Vara Única', '147,36%'],
#  ['Sobral - 1ª Vara', '125,88%'],
#  ['Sobral - 2ª Vara', '98,37%'],
#  ['Tianguá - Vara Única', '100,95%']]

# %%
# Removendo linhas duplicadas
tableFull = [list(tupla) for tupla in set(tuple(lista) for lista in tableFull)]
tableFull
# Out:
# [['Região do Cariri - 2ª Vara', '-1,11%'],
#  ['Fortaleza - 10ª Vara', '137,38%'],
#  ['Fortaleza - 8ª Vara', '134,31%'],
#  ['Região do Cariri - 3ª Vara', '-1,16%'],
#  ['Caucaia - 1ª Vara', '204,63%'],
#  ['Maracanaú - 1ª Vara', '126,10%'],
#  ['Fortaleza - 13ª Vara', '110,62%'],
#  ['Tianguá - Vara Única', '100,95%'],
#  ['Fortaleza - 16ª Vara', '144,65%'],
#  ['Pacajus - Vara Única', '134,79%'],
#  ['Eusébio - Vara Única', '120,91%'],
#  ['Sobral - 2ª Vara', '98,37%'],
#  ['Baturité - Vara Única', '100,88%'],
#  ['Fortaleza - 2ª Vara', '134,90%'],
#  ['Iguatu - Vara Única', '111,43%'],
#  ['Limoeiro do Norte - Vara Única', '81,18%'],
#  ['Fortaleza - 9ª Vara', '105,16%'],
#  ['Fortaleza - 1ª Vara', '115,20%'],
#  ['Fortaleza - 7ª Vara', '123,25%'],
#  ['Fortaleza - 15ª Vara', '130,64%'],
#  ['Fortaleza - 12ª Vara', '117,05%'],
#  ['Crateús - Vara Única', '119,32%'],
#  ['São Gonçalo do Amarante - Vara Única', '147,36%'],
#  ['Fortaleza - 11ª Vara', '198,32%'],
#  ['Fortaleza - 6ª Vara', '77,35%'],
#  ['Fortaleza - 4ª Vara', '114,27%'],
#  ['Sobral - 1ª Vara', '125,88%'],
#  ['Fortaleza - 5ª Vara', '145,31%'],
#  ['Fortaleza - 18ª Vara', '66,85%'],
#  ['Maracanaú - 2ª Vara', '114,26%'],
#  ['Fortaleza - 14ª Vara', '172,53%'],
#  ['Quixadá - Vara Única', '105,75%'],
#  ['Caucaia - 2ª Vara', '105,81%'],
#  ['Fortaleza - 3ª Vara', '112,41%'],
#  ['Região do Cariri - 1ª Vara', '-1,41%'],
#  ['Aracati - Vara Única', '118,73%'],
#  ['Fortaleza - 17ª Vara', '137,22%']]

# %%
meta5_23 = pd.DataFrame(tableFull)
meta5_23.columns = ['Unidade Judiciária', 'Resultado']
meta5_23['Unidade Judiciária'] = meta5_23['Unidade Judiciária'].apply(lambda orgao: conversorNomeVara[orgao])
meta5_23.loc[len(meta5_23)] = total1grau
meta5_23.loc[len(meta5_23)] = totaltrt7
meta5_23.insert(0, 'Índices', meta5_23['Unidade Judiciária'].map(id_vara))

# Inserindo o Ano
meta5_23.insert(2, 'Ano', 2023)
meta5_23.sort_values(by=['Ano', 'Índices'], ascending=[True, True], inplace=True)
meta5_23
# Out:
#     Índices                Unidade Judiciária   Ano Resultado
# 17        1                1ª VT de Fortaleza  2023   115,20%
# 13        2                2ª VT de Fortaleza  2023   134,90%
# 33        3                3ª VT de Fortaleza  2023   112,41%
# 25        4                4ª VT de Fortaleza  2023   114,27%
# 27        5                5ª VT de Fortaleza  2023   145,31%
# 24        6                6ª VT de Fortaleza  2023    77,35%
# 18        7                7ª VT de Fortaleza  2023   123,25%
# 2         8                8ª VT de Fortaleza  2023   134,31%
# 16        9                9ª VT de Fortaleza  2023   105,16%
# 1        10               10ª VT de Fortaleza  2023   137,38%
# 23       11               11ª VT de Fortaleza  2023   198,32%
# 20       12               12ª VT de Fortaleza  2023   117,05%
# 6        13               13ª VT de Fortaleza  2023   110,62%
# 30       14               14ª VT de Fortaleza  2023   172,53%
# 19       15               15ª VT de Fortaleza  2023   130,64%
# 8        16               16ª VT de Fortaleza  2023   144,65%
# 36       17               17ª VT de Fortaleza  2023   137,22%
# 28       18               18ª VT de Fortaleza  2023    66,85%
# 35       19                  1ª VT de Aracati  2023   118,73%
# 12       20                 1ª VT de Baturité  2023   100,88%
# 4        21                  1ª VT de Caucaia  2023   204,63%
# 21       22                  1ª VT de Crateus  2023   119,32%
# 10       23                  1ª VT de Eusébio  2023   120,91%
# 14       24                   1ª VT de Iguatu  2023   111,43%
# 34       25         1ª VT da Região do Cariri  2023    -1,41%
# 15       26        1ª VT de Limoeiro do Norte  2023    81,18%
# 5        27                1ª VT de Maracanau  2023   126,10%
# 9        28                  1ª VT de Pacajus  2023   134,79%
# 31       29                  1ª VT de Quixadá  2023   105,75%
# 22       30  1ª VT de São Gonçalo do Amarante  2023   147,36%
# 26       31                   1ª VT de Sobral  2023   125,88%
# 7        32                  1ª VT de Tianguá  2023   100,95%
# 32       33                  2ª VT de Caucaia  2023   105,81%
# 0        34         2ª VT da Região do Cariri  2023    -1,11%
# 29       35                2ª VT de Maracanau  2023   114,26%
# 11       36                   2ª VT de Sobral  2023    98,37%
# 3        37         3ª VT da Região do Cariri  2023    -1,16%
# 37       38                  Total do 1º Grau  2023   123,32%
# 38       39                Total da 7ª Região  2023   114,47%

# %%
driver.close()

# %% [markdown]
# # Meta 5- 2024

# %%
# Meta 5 - 2024
# Iniciando navegador
driver = webdriver.Chrome()
sleep(3)

# %%
# Entrando no site
driver.get(ano[2024])
sleep(12)

# %%
# Clicando na meta 
driver.find_elements(By.CLASS_NAME, 'tileSVG')[4].click()
sleep(3)

# %%
# Selecionando o UF
driver.find_elements(By.CSS_SELECTOR, '.slicer-dropdown-menu')[3].click()
sleep(2)

# %%
# Selecionando 07ª - CE
driver.find_elements(By.CSS_SELECTOR, '.slicerText')[7].click()
sleep(5)

# %%
# Selecionando a 1º Instância
driver.find_elements(By.CSS_SELECTOR, '.slicer-dropdown-menu')[0].click()
sleep(2)

driver.find_elements(By.CSS_SELECTOR, '.slicerText')[1].click()
sleep(5)

# %%
table = driver.find_elements(By.XPATH, '//*[@id="pvExplorationHost"]/div/div/exploration/div/explore-canvas/div/div[2]/div/div[2]/div[2]/visual-container-repeat/visual-container[16]/transform/div/div[3]/div/div/visual-modern/div/div/div[2]/div[1]/div[2]/div/div')
table = [r.text for r in table]
table
# Out:
# ['Aracati - Vara Única\n1.412\n688\n32,76%\nFormatação Condicional Adicional\n21,21%\n40,85%\n120,18%',
#  'Baturité - Vara Única\n576\n329\n36,35%\nFormatação Condicional Adicional\n38,83%\n34,46%\n159,57%',
#  'Caucaia - 1ª Vara\n2.074\n1.022\n33,01%\nFormatação Condicional Adicional\n25,75%\n39,58%\n96,82%',
#  'Caucaia - 2ª Vara\n1.679\n754\n30,99%\nFormatação Condicional Adicional\n26,82%\n38,15%\n135,41%',
#  'Crateús - Vara Única\n3.325\n1.592\n32,38%\nFormatação Condicional Adicional\n21,33%\n48,92%\n103,20%',
#  'Eusébio - Vara Única\n2.872\n1.009\n26,00%\nFormatação Condicional Adicional\n27,74%\n22,12%\n89,26%',
#  'Fortaleza - 10ª Vara\n2.874\n1.419\n33,05%\nFormatação Condicional Adicional\n22,39%\n40,23%\n123,65%',
#  'Fortaleza - 11ª Vara\n2.648\n866\n24,64%\nFormatação Condicional Adicional\n21,80%\n25,05%\n106,96%',
#  'Fortaleza - 12ª Vara\n2.131\n2.559\n54,56%\nFormatação Condicional Adicional\n33,02%\n67,62%\n95,08%',
#  'Fortaleza - 13ª Vara\n2.440\n1.551\n38,86%\nFormatação Condicional Adicional\n32,87%\n43,43%\n107,20%',
#  'Fortaleza - 14ª Vara\n2.502\n947\n27,46%\nFormatação Condicional Adicional\n20,94%\n33,72%\n112,65%',
#  'Fortaleza - 15ª Vara\n2.212\n1.652\n42,75%\nFormatação Condicional Adicional\n30,33%\n54,66%\n96,06%',
#  'Fortaleza - 16ª Vara\n1.994\n1.203\n37,63%\nFormatação Condicional Adicional\n31,55%\n43,86%\n77,07%',
#  'Fortaleza - 17ª Vara\n2.116\n1.931\n47,71%\nFormatação Condicional Adicional\n37,13%\n56,72%\n89,65%',
#  'Fortaleza - 18ª Vara\n2.020\n674\n25,02%\nFormatação Condicional Adicional\n20,74%\n30,22%\n106,12%',
#  'Fortaleza - 1ª Vara\n2.499\n1.358\n35,21%\nFormatação Condicional Adicional\n17,12%\n46,75%\n121,08%',
#  'Fortaleza - 2ª Vara\n2.589\n1.534\n37,21%\nFormatação Condicional Adicional\n30,61%\n42,45%\n108,54%',
#  'Fortaleza - 3ª Vara\n3.308\n2.743\n45,33%\nFormatação Condicional Adicional\n24,99%\n55,94%\n127,50%',
#  'Fortaleza - 4ª Vara\n2.133\n2.920\n57,79%\nFormatação Condicional Adicional\n40,86%\n68,69%\n102,48%',
#  'Fortaleza - 5ª Vara\n2.845\n1.697\n37,36%\nFormatação Condicional Adicional\n23,75%\n48,56%\n107,48%']

# %%
# Tabela só é usada para scrollar afim de obter a outra parte das linhas, table que armazena os dados
tabela = driver.find_elements(By.CLASS_NAME, 'mid-viewport')[1]
driver.execute_script("arguments[0].scrollTop += 500;", tabela)
sleep(2)

# %%
table2 = driver.find_elements(By.XPATH, '//*[@id="pvExplorationHost"]/div/div/exploration/div/explore-canvas/div/div[2]/div/div[2]/div[2]/visual-container-repeat/visual-container[16]/transform/div/div[3]/div/div/visual-modern/div/div/div[2]/div[1]/div[2]/div/div')
table2 = [r.text for r in table2]
table2
# Out:
# ['Fortaleza - 5ª Vara\n2.845\n1.697\n37,36%\nFormatação Condicional Adicional\n23,75%\n48,56%\n107,48%',
#  'Fortaleza - 6ª Vara\n3.438\n814\n19,14%\nFormatação Condicional Adicional\n15,93%\n21,87%\n274,71%',
#  'Fortaleza - 7ª Vara\n1.579\n2.222\n58,46%\nFormatação Condicional Adicional\n46,89%\n71,11%\n75,31%',
#  'Fortaleza - 8ª Vara\n2.161\n1.326\n38,03%\nFormatação Condicional Adicional\n29,87%\n46,44%\n92,72%',
#  'Fortaleza - 9ª Vara\n2.791\n2.429\n46,53%\nFormatação Condicional Adicional\n43,77%\n48,24%\n118,08%',
#  'Iguatu - Vara Única\n3.590\n1.373\n27,66%\nFormatação Condicional Adicional\n24,05%\n30,90%\n115,71%',
#  'Limoeiro do Norte - Vara Única\n2.349\n1.028\n30,44%\nFormatação Condicional Adicional\n34,20%\n27,66%\n129,23%',
#  'Maracanaú - 1ª Vara\n2.427\n1.043\n30,06%\nFormatação Condicional Adicional\n27,55%\n33,53%\n92,33%',
#  'Maracanaú - 2ª Vara\n2.532\n730\n22,38%\nFormatação Condicional Adicional\n20,27%\n25,15%\n98,56%',
#  'Pacajus - Vara Única\n2.263\n1.178\n34,23%\nFormatação Condicional Adicional\n34,41%\n32,97%\n100,25%',
#  'Quixadá - Vara Única\n2.081\n1.571\n43,02%\nFormatação Condicional Adicional\n45,73%\n40,77%\n125,01%',
#  'Região do Cariri - 1ª Vara\n3.434\n1.246\n26,62%\nFormatação Condicional Adicional\n22,46%\n29,68%\n131,73%',
#  'Região do Cariri - 2ª Vara\n3.642\n2.552\n41,20%\nFormatação Condicional Adicional\n22,88%\n48,96%\n108,43%',
#  'Região do Cariri - 3ª Vara\n3.746\n1.429\n27,61%\nFormatação Condicional Adicional\n23,76%\n30,10%\n154,17%',
#  'São Gonçalo do Amarante - Vara Única\n3.534\n1.077\n23,36%\nFormatação Condicional Adicional\n21,51%\n25,94%\n90,13%',
#  'Sobral - 1ª Vara\n3.194\n850\n21,02%\nFormatação Condicional Adicional\n14,39%\n31,97%\n138,28%',
#  'Sobral - 2ª Vara\n2.836\n847\n23,00%\nFormatação Condicional Adicional\n14,14%\n33,82%\n115,58%',
#  'Tianguá - Vara Única\n2.704\n1.594\n37,09%\nFormatação Condicional Adicional\n31,00%\n38,94%\n82,31%']

# %%
total1grau = driver.find_elements(By.XPATH, '//*[@id="pvExplorationHost"]/div/div/exploration/div/explore-canvas/div/div[2]/div/div[2]/div[2]/visual-container-repeat/visual-container[16]/transform/div/div[3]/div/div/visual-modern/div/div/div[2]/div[1]/div[3]/div')
total1grau = [r.text for r in total1grau]
total1grau = [r.split('\n') for r in total1grau]
total1grau = total1grau[0]
total1grau = [total1grau[0], total1grau[-1]]
total1grau[0] = 'Total do 1º Grau'
sleep(2)
total1grau
# Out:
# ['Total do 1º Grau', '110,39%']

# %%
# Selecionando todos os graus
driver.find_elements(By.CSS_SELECTOR, '.slicerText')[1].click()
sleep(5)

# %%
totaltrt7 = driver.find_elements(By.XPATH, '//*[@id="pvExplorationHost"]/div/div/exploration/div/explore-canvas/div/div[2]/div/div[2]/div[2]/visual-container-repeat/visual-container[12]/transform/div/div[3]/div/div/visual-modern/div/div/div[2]/div[1]/div[3]/div')
totaltrt7 = [r.text for r in totaltrt7]
totaltrt7 = [r.split('\n') for r in totaltrt7]
totaltrt7 = totaltrt7[0]
totaltrt7 = [totaltrt7[0], totaltrt7[-1]]
totaltrt7[0] = 'Total da 7ª Região'
totaltrt7
# Out:
# ['Total da 7ª Região', '112,14%']

# %%
tableFull = table + table2 
tableFull
# Out:
# ['Aracati - Vara Única\n1.412\n688\n32,76%\nFormatação Condicional Adicional\n21,21%\n40,85%\n120,18%',
#  'Baturité - Vara Única\n576\n329\n36,35%\nFormatação Condicional Adicional\n38,83%\n34,46%\n159,57%',
#  'Caucaia - 1ª Vara\n2.074\n1.022\n33,01%\nFormatação Condicional Adicional\n25,75%\n39,58%\n96,82%',
#  'Caucaia - 2ª Vara\n1.679\n754\n30,99%\nFormatação Condicional Adicional\n26,82%\n38,15%\n135,41%',
#  'Crateús - Vara Única\n3.325\n1.592\n32,38%\nFormatação Condicional Adicional\n21,33%\n48,92%\n103,20%',
#  'Eusébio - Vara Única\n2.872\n1.009\n26,00%\nFormatação Condicional Adicional\n27,74%\n22,12%\n89,26%',
#  'Fortaleza - 10ª Vara\n2.874\n1.419\n33,05%\nFormatação Condicional Adicional\n22,39%\n40,23%\n123,65%',
#  'Fortaleza - 11ª Vara\n2.648\n866\n24,64%\nFormatação Condicional Adicional\n21,80%\n25,05%\n106,96%',
#  'Fortaleza - 12ª Vara\n2.131\n2.559\n54,56%\nFormatação Condicional Adicional\n33,02%\n67,62%\n95,08%',
#  'Fortaleza - 13ª Vara\n2.440\n1.551\n38,86%\nFormatação Condicional Adicional\n32,87%\n43,43%\n107,20%',
#  'Fortaleza - 14ª Vara\n2.502\n947\n27,46%\nFormatação Condicional Adicional\n20,94%\n33,72%\n112,65%',
#  'Fortaleza - 15ª Vara\n2.212\n1.652\n42,75%\nFormatação Condicional Adicional\n30,33%\n54,66%\n96,06%',
#  'Fortaleza - 16ª Vara\n1.994\n1.203\n37,63%\nFormatação Condicional Adicional\n31,55%\n43,86%\n77,07%',
#  'Fortaleza - 17ª Vara\n2.116\n1.931\n47,71%\nFormatação Condicional Adicional\n37,13%\n56,72%\n89,65%',
#  'Fortaleza - 18ª Vara\n2.020\n674\n25,02%\nFormatação Condicional Adicional\n20,74%\n30,22%\n106,12%',
#  'Fortaleza - 1ª Vara\n2.499\n1.358\n35,21%\nFormatação Condicional Adicional\n17,12%\n46,75%\n121,08%',
#  'Fortaleza - 2ª Vara\n2.589\n1.534\n37,21%\nFormatação Condicional Adicional\n30,61%\n42,45%\n108,54%',
#  'Fortaleza - 3ª Vara\n3.308\n2.743\n45,33%\nFormatação Condicional Adicional\n24,99%\n55,94%\n127,50%',
#  'Fortaleza - 4ª Vara\n2.133\n2.920\n57,79%\nFormatação Condicional Adicional\n40,86%\n68,69%\n102,48%',
#  'Fortaleza - 5ª Vara\n2.845\n1.697\n37,36%\nFormatação Condicional Adicional\n23,75%\n48,56%\n107,48%',
#  'Fortaleza - 5ª Vara\n2.845\n1.697\n37,36%\nFormatação Condicional Adicional\n23,75%\n48,56%\n107,48%',
#  'Fortaleza - 6ª Vara\n3.438\n814\n19,14%\nFormatação Condicional Adicional\n15,93%\n21,87%\n274,71%',
#  'Fortaleza - 7ª Vara\n1.579\n2.222\n58,46%\nFormatação Condicional Adicional\n46,89%\n71,11%\n75,31%',
#  'Fortaleza - 8ª Vara\n2.161\n1.326\n38,03%\nFormatação Condicional Adicional\n29,87%\n46,44%\n92,72%',
#  'Fortaleza - 9ª Vara\n2.791\n2.429\n46,53%\nFormatação Condicional Adicional\n43,77%\n48,24%\n118,08%',
#  'Iguatu - Vara Única\n3.590\n1.373\n27,66%\nFormatação Condicional Adicional\n24,05%\n30,90%\n115,71%',
#  'Limoeiro do Norte - Vara Única\n2.349\n1.028\n30,44%\nFormatação Condicional Adicional\n34,20%\n27,66%\n129,23%',
#  'Maracanaú - 1ª Vara\n2.427\n1.043\n30,06%\nFormatação Condicional Adicional\n27,55%\n33,53%\n92,33%',
#  'Maracanaú - 2ª Vara\n2.532\n730\n22,38%\nFormatação Condicional Adicional\n20,27%\n25,15%\n98,56%',
#  'Pacajus - Vara Única\n2.263\n1.178\n34,23%\nFormatação Condicional Adicional\n34,41%\n32,97%\n100,25%',
#  'Quixadá - Vara Única\n2.081\n1.571\n43,02%\nFormatação Condicional Adicional\n45,73%\n40,77%\n125,01%',
#  'Região do Cariri - 1ª Vara\n3.434\n1.246\n26,62%\nFormatação Condicional Adicional\n22,46%\n29,68%\n131,73%',
#  'Região do Cariri - 2ª Vara\n3.642\n2.552\n41,20%\nFormatação Condicional Adicional\n22,88%\n48,96%\n108,43%',
#  'Região do Cariri - 3ª Vara\n3.746\n1.429\n27,61%\nFormatação Condicional Adicional\n23,76%\n30,10%\n154,17%',
#  'São Gonçalo do Amarante - Vara Única\n3.534\n1.077\n23,36%\nFormatação Condicional Adicional\n21,51%\n25,94%\n90,13%',
#  'Sobral - 1ª Vara\n3.194\n850\n21,02%\nFormatação Condicional Adicional\n14,39%\n31,97%\n138,28%',
#  'Sobral - 2ª Vara\n2.836\n847\n23,00%\nFormatação Condicional Adicional\n14,14%\n33,82%\n115,58%',
#  'Tianguá - Vara Única\n2.704\n1.594\n37,09%\nFormatação Condicional Adicional\n31,00%\n38,94%\n82,31%']

# %%
# Transforma cada linha em uma lista separada por \n 
tableFull = [r.split('\n') for r in tableFull]
tableFull
# Out:
# [['Aracati - Vara Única',
#   '1.412',
#   '688',
#   '32,76%',
#   'Formatação Condicional Adicional',
#   '21,21%',
#   '40,85%',
#   '120,18%'],
#  ['Baturité - Vara Única',
#   '576',
#   '329',
#   '36,35%',
#   'Formatação Condicional Adicional',
#   '38,83%',
#   '34,46%',
#   '159,57%'],
#  ['Caucaia - 1ª Vara',
#   '2.074',
#   '1.022',
#   '33,01%',
#   'Formatação Condicional Adicional',
#   '25,75%',
#   '39,58%',
#   '96,82%'],
#  ['Caucaia - 2ª Vara',
#   '1.679',
#   '754',
#   '30,99%',
#   'Formatação Condicional Adicional',
#   '26,82%',
#   '38,15%',
#   '135,41%'],
#  ['Crateús - Vara Única',
#   '3.325',
#   '1.592',
#   '32,38%',
#   'Formatação Condicional Adicional',
#   '21,33%',
#   '48,92%',
#   '103,20%'],
#  ['Eusébio - Vara Única',
#   '2.872',
#   '1.009',
#   '26,00%',
#   'Formatação Condicional Adicional',
#   '27,74%',
#   '22,12%',
#   '89,26%'],
#  ['Fortaleza - 10ª Vara',
#   '2.874',
#   '1.419',
#   '33,05%',
#   'Formatação Condicional Adicional',
#   '22,39%',
#   '40,23%',
#   '123,65%'],
#  ['Fortaleza - 11ª Vara',
#   '2.648',
#   '866',
#   '24,64%',
#   'Formatação Condicional Adicional',
#   '21,80%',
#   '25,05%',
#   '106,96%'],
#  ['Fortaleza - 12ª Vara',
#   '2.131',
#   '2.559',
#   '54,56%',
#   'Formatação Condicional Adicional',
#   '33,02%',
#   '67,62%',
#   '95,08%'],
#  ['Fortaleza - 13ª Vara',
#   '2.440',
#   '1.551',
#   '38,86%',
#   'Formatação Condicional Adicional',
#   '32,87%',
#   '43,43%',
#   '107,20%'],
#  ['Fortaleza - 14ª Vara',
#   '2.502',
#   '947',
#   '27,46%',
#   'Formatação Condicional Adicional',
#   '20,94%',
#   '33,72%',
#   '112,65%'],
#  ['Fortaleza - 15ª Vara',
#   '2.212',
#   '1.652',
#   '42,75%',
#   'Formatação Condicional Adicional',
#   '30,33%',
#   '54,66%',
#   '96,06%'],
#  ['Fortaleza - 16ª Vara',
#   '1.994',
#   '1.203',
#   '37,63%',
#   'Formatação Condicional Adicional',
#   '31,55%',
#   '43,86%',
#   '77,07%'],
#  ['Fortaleza - 17ª Vara',
#   '2.116',
#   '1.931',
#   '47,71%',
#   'Formatação Condicional Adicional',
#   '37,13%',
#   '56,72%',
#   '89,65%'],
#  ['Fortaleza - 18ª Vara',
#   '2.020',
#   '674',
#   '25,02%',
#   'Formatação Condicional Adicional',
#   '20,74%',
#   '30,22%',
#   '106,12%'],
#  ['Fortaleza - 1ª Vara',
#   '2.499',
#   '1.358',
#   '35,21%',
#   'Formatação Condicional Adicional',
#   '17,12%',
#   '46,75%',
#   '121,08%'],
#  ['Fortaleza - 2ª Vara',
#   '2.589',
#   '1.534',
#   '37,21%',
#   'Formatação Condicional Adicional',
#   '30,61%',
#   '42,45%',
#   '108,54%'],
#  ['Fortaleza - 3ª Vara',
#   '3.308',
#   '2.743',
#   '45,33%',
#   'Formatação Condicional Adicional',
#   '24,99%',
#   '55,94%',
#   '127,50%'],
#  ['Fortaleza - 4ª Vara',
#   '2.133',
#   '2.920',
#   '57,79%',
#   'Formatação Condicional Adicional',
#   '40,86%',
#   '68,69%',
#   '102,48%'],
#  ['Fortaleza - 5ª Vara',
#   '2.845',
#   '1.697',
#   '37,36%',
#   'Formatação Condicional Adicional',
#   '23,75%',
#   '48,56%',
#   '107,48%'],
#  ['Fortaleza - 5ª Vara',
#   '2.845',
#   '1.697',
#   '37,36%',
#   'Formatação Condicional Adicional',
#   '23,75%',
#   '48,56%',
#   '107,48%'],
#  ['Fortaleza - 6ª Vara',
#   '3.438',
#   '814',
#   '19,14%',
#   'Formatação Condicional Adicional',
#   '15,93%',
#   '21,87%',
#   '274,71%'],
#  ['Fortaleza - 7ª Vara',
#   '1.579',
#   '2.222',
#   '58,46%',
#   'Formatação Condicional Adicional',
#   '46,89%',
#   '71,11%',
#   '75,31%'],
#  ['Fortaleza - 8ª Vara',
#   '2.161',
#   '1.326',
#   '38,03%',
#   'Formatação Condicional Adicional',
#   '29,87%',
#   '46,44%',
#   '92,72%'],
#  ['Fortaleza - 9ª Vara',
#   '2.791',
#   '2.429',
#   '46,53%',
#   'Formatação Condicional Adicional',
#   '43,77%',
#   '48,24%',
#   '118,08%'],
#  ['Iguatu - Vara Única',
#   '3.590',
#   '1.373',
#   '27,66%',
#   'Formatação Condicional Adicional',
#   '24,05%',
#   '30,90%',
#   '115,71%'],
#  ['Limoeiro do Norte - Vara Única',
#   '2.349',
#   '1.028',
#   '30,44%',
#   'Formatação Condicional Adicional',
#   '34,20%',
#   '27,66%',
#   '129,23%'],
#  ['Maracanaú - 1ª Vara',
#   '2.427',
#   '1.043',
#   '30,06%',
#   'Formatação Condicional Adicional',
#   '27,55%',
#   '33,53%',
#   '92,33%'],
#  ['Maracanaú - 2ª Vara',
#   '2.532',
#   '730',
#   '22,38%',
#   'Formatação Condicional Adicional',
#   '20,27%',
#   '25,15%',
#   '98,56%'],
#  ['Pacajus - Vara Única',
#   '2.263',
#   '1.178',
#   '34,23%',
#   'Formatação Condicional Adicional',
#   '34,41%',
#   '32,97%',
#   '100,25%'],
#  ['Quixadá - Vara Única',
#   '2.081',
#   '1.571',
#   '43,02%',
#   'Formatação Condicional Adicional',
#   '45,73%',
#   '40,77%',
#   '125,01%'],
#  ['Região do Cariri - 1ª Vara',
#   '3.434',
#   '1.246',
#   '26,62%',
#   'Formatação Condicional Adicional',
#   '22,46%',
#   '29,68%',
#   '131,73%'],
#  ['Região do Cariri - 2ª Vara',
#   '3.642',
#   '2.552',
#   '41,20%',
#   'Formatação Condicional Adicional',
#   '22,88%',
#   '48,96%',
#   '108,43%'],
#  ['Região do Cariri - 3ª Vara',
#   '3.746',
#   '1.429',
#   '27,61%',
#   'Formatação Condicional Adicional',
#   '23,76%',
#   '30,10%',
#   '154,17%'],
#  ['São Gonçalo do Amarante - Vara Única',
#   '3.534',
#   '1.077',
#   '23,36%',
#   'Formatação Condicional Adicional',
#   '21,51%',
#   '25,94%',
#   '90,13%'],
#  ['Sobral - 1ª Vara',
#   '3.194',
#   '850',
#   '21,02%',
#   'Formatação Condicional Adicional',
#   '14,39%',
#   '31,97%',
#   '138,28%'],
#  ['Sobral - 2ª Vara',
#   '2.836',
#   '847',
#   '23,00%',
#   'Formatação Condicional Adicional',
#   '14,14%',
#   '33,82%',
#   '115,58%'],
#  ['Tianguá - Vara Única',
#   '2.704',
#   '1.594',
#   '37,09%',
#   'Formatação Condicional Adicional',
#   '31,00%',
#   '38,94%',
#   '82,31%']]

# %%
# Remove todos os elementos de cada linha(lista), deixando apenas o primeiro e último (unidade judiciária e cumprimento da meta)
tableFull = [[l[0], l[-1]] for l in tableFull]
tableFull
# Out:
# [['Aracati - Vara Única', '120,18%'],
#  ['Baturité - Vara Única', '159,57%'],
#  ['Caucaia - 1ª Vara', '96,82%'],
#  ['Caucaia - 2ª Vara', '135,41%'],
#  ['Crateús - Vara Única', '103,20%'],
#  ['Eusébio - Vara Única', '89,26%'],
#  ['Fortaleza - 10ª Vara', '123,65%'],
#  ['Fortaleza - 11ª Vara', '106,96%'],
#  ['Fortaleza - 12ª Vara', '95,08%'],
#  ['Fortaleza - 13ª Vara', '107,20%'],
#  ['Fortaleza - 14ª Vara', '112,65%'],
#  ['Fortaleza - 15ª Vara', '96,06%'],
#  ['Fortaleza - 16ª Vara', '77,07%'],
#  ['Fortaleza - 17ª Vara', '89,65%'],
#  ['Fortaleza - 18ª Vara', '106,12%'],
#  ['Fortaleza - 1ª Vara', '121,08%'],
#  ['Fortaleza - 2ª Vara', '108,54%'],
#  ['Fortaleza - 3ª Vara', '127,50%'],
#  ['Fortaleza - 4ª Vara', '102,48%'],
#  ['Fortaleza - 5ª Vara', '107,48%'],
#  ['Fortaleza - 5ª Vara', '107,48%'],
#  ['Fortaleza - 6ª Vara', '274,71%'],
#  ['Fortaleza - 7ª Vara', '75,31%'],
#  ['Fortaleza - 8ª Vara', '92,72%'],
#  ['Fortaleza - 9ª Vara', '118,08%'],
#  ['Iguatu - Vara Única', '115,71%'],
#  ['Limoeiro do Norte - Vara Única', '129,23%'],
#  ['Maracanaú - 1ª Vara', '92,33%'],
#  ['Maracanaú - 2ª Vara', '98,56%'],
#  ['Pacajus - Vara Única', '100,25%'],
#  ['Quixadá - Vara Única', '125,01%'],
#  ['Região do Cariri - 1ª Vara', '131,73%'],
#  ['Região do Cariri - 2ª Vara', '108,43%'],
#  ['Região do Cariri - 3ª Vara', '154,17%'],
#  ['São Gonçalo do Amarante - Vara Única', '90,13%'],
#  ['Sobral - 1ª Vara', '138,28%'],
#  ['Sobral - 2ª Vara', '115,58%'],
#  ['Tianguá - Vara Única', '82,31%']]

# %%
# Removendo linhas duplicadas
tableFull = [list(tupla) for tupla in set(tuple(lista) for lista in tableFull)]
tableFull
# Out:
# [['Baturité - Vara Única', '159,57%'],
#  ['Fortaleza - 17ª Vara', '89,65%'],
#  ['Região do Cariri - 3ª Vara', '154,17%'],
#  ['Fortaleza - 7ª Vara', '75,31%'],
#  ['Limoeiro do Norte - Vara Única', '129,23%'],
#  ['Fortaleza - 11ª Vara', '106,96%'],
#  ['Região do Cariri - 1ª Vara', '131,73%'],
#  ['Fortaleza - 10ª Vara', '123,65%'],
#  ['Pacajus - Vara Única', '100,25%'],
#  ['Sobral - 2ª Vara', '115,58%'],
#  ['Fortaleza - 8ª Vara', '92,72%'],
#  ['Caucaia - 2ª Vara', '135,41%'],
#  ['Fortaleza - 3ª Vara', '127,50%'],
#  ['Eusébio - Vara Única', '89,26%'],
#  ['Caucaia - 1ª Vara', '96,82%'],
#  ['São Gonçalo do Amarante - Vara Única', '90,13%'],
#  ['Tianguá - Vara Única', '82,31%'],
#  ['Crateús - Vara Única', '103,20%'],
#  ['Fortaleza - 6ª Vara', '274,71%'],
#  ['Fortaleza - 14ª Vara', '112,65%'],
#  ['Fortaleza - 15ª Vara', '96,06%'],
#  ['Aracati - Vara Única', '120,18%'],
#  ['Fortaleza - 1ª Vara', '121,08%'],
#  ['Maracanaú - 2ª Vara', '98,56%'],
#  ['Fortaleza - 16ª Vara', '77,07%'],
#  ['Região do Cariri - 2ª Vara', '108,43%'],
#  ['Fortaleza - 18ª Vara', '106,12%'],
#  ['Fortaleza - 12ª Vara', '95,08%'],
#  ['Fortaleza - 9ª Vara', '118,08%'],
#  ['Iguatu - Vara Única', '115,71%'],
#  ['Fortaleza - 13ª Vara', '107,20%'],
#  ['Fortaleza - 4ª Vara', '102,48%'],
#  ['Fortaleza - 2ª Vara', '108,54%'],
#  ['Fortaleza - 5ª Vara', '107,48%'],
#  ['Quixadá - Vara Única', '125,01%'],
#  ['Maracanaú - 1ª Vara', '92,33%'],
#  ['Sobral - 1ª Vara', '138,28%']]

# %%
meta5_24 = pd.DataFrame(tableFull)
meta5_24.columns = ['Unidade Judiciária', 'Resultado']
meta5_24['Unidade Judiciária'] = meta5_24['Unidade Judiciária'].apply(lambda orgao: conversorNomeVara[orgao])
meta5_24.loc[len(meta5_24)] = total1grau
meta5_24.loc[len(meta5_24)] = totaltrt7
meta5_24.insert(0, 'Índices', meta5_24['Unidade Judiciária'].map(id_vara))

# Inserindo o Ano
meta5_24.insert(2, 'Ano', 2024)
meta5_24.sort_values(by=['Ano', 'Índices'], ascending=[True, True], inplace=True)
meta5_24
# Out:
#     Índices                Unidade Judiciária   Ano Resultado
# 22        1                1ª VT de Fortaleza  2024   121,08%
# 32        2                2ª VT de Fortaleza  2024   108,54%
# 12        3                3ª VT de Fortaleza  2024   127,50%
# 31        4                4ª VT de Fortaleza  2024   102,48%
# 33        5                5ª VT de Fortaleza  2024   107,48%
# 18        6                6ª VT de Fortaleza  2024   274,71%
# 3         7                7ª VT de Fortaleza  2024    75,31%
# 10        8                8ª VT de Fortaleza  2024    92,72%
# 28        9                9ª VT de Fortaleza  2024   118,08%
# 7        10               10ª VT de Fortaleza  2024   123,65%
# 5        11               11ª VT de Fortaleza  2024   106,96%
# 27       12               12ª VT de Fortaleza  2024    95,08%
# 30       13               13ª VT de Fortaleza  2024   107,20%
# 19       14               14ª VT de Fortaleza  2024   112,65%
# 20       15               15ª VT de Fortaleza  2024    96,06%
# 24       16               16ª VT de Fortaleza  2024    77,07%
# 1        17               17ª VT de Fortaleza  2024    89,65%
# 26       18               18ª VT de Fortaleza  2024   106,12%
# 21       19                  1ª VT de Aracati  2024   120,18%
# 0        20                 1ª VT de Baturité  2024   159,57%
# 14       21                  1ª VT de Caucaia  2024    96,82%
# 17       22                  1ª VT de Crateus  2024   103,20%
# 13       23                  1ª VT de Eusébio  2024    89,26%
# 29       24                   1ª VT de Iguatu  2024   115,71%
# 6        25         1ª VT da Região do Cariri  2024   131,73%
# 4        26        1ª VT de Limoeiro do Norte  2024   129,23%
# 35       27                1ª VT de Maracanau  2024    92,33%
# 8        28                  1ª VT de Pacajus  2024   100,25%
# 34       29                  1ª VT de Quixadá  2024   125,01%
# 15       30  1ª VT de São Gonçalo do Amarante  2024    90,13%
# 36       31                   1ª VT de Sobral  2024   138,28%
# 16       32                  1ª VT de Tianguá  2024    82,31%
# 11       33                  2ª VT de Caucaia  2024   135,41%
# 25       34         2ª VT da Região do Cariri  2024   108,43%
# 23       35                2ª VT de Maracanau  2024    98,56%
# 9        36                   2ª VT de Sobral  2024   115,58%
# 2        37         3ª VT da Região do Cariri  2024   154,17%
# 37       38                  Total do 1º Grau  2024   110,39%
# 38       39                Total da 7ª Região  2024   112,14%

# %%
meta5 = pd.concat([meta5_23, meta5_24], ignore_index=True)
meta5.sort_values(by=['Ano', 'Índices'], ascending=[True, True], inplace=True)
meta5.to_csv('Resultados/Correições 2024 - Meta 5.csv', sep=',', index=False)
driver.close()
